# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.value_counts('Species')
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
df.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm')
plt.show()

# %%
df.plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm')
plt.show()

# %%
sns.set_style('white')
sns.FacetGrid(df,hue='Species', aspect=2) \
    .map(plt.scatter,'SepalLengthCm','SepalWidthCm') \
    .add_legend()
plt.show()

# %%
sns.set_style('white')
sns.FacetGrid(df,hue='Species', aspect=2) \
    .map(plt.scatter,'PetalLengthCm','PetalWidthCm') \
    .add_legend()
plt.show()

# %%
sns.set_style('dark')
sns.FacetGrid(df,hue='Species', aspect=2) \
    .map(sns.distplot,'PetalLengthCm') \
    .add_legend()
plt.show()
# Out:
# c:\python\python37\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\python\python37\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.set_style('white')
sns.FacetGrid(df,hue='Species', aspect=2) \
    .map(sns.distplot,'PetalWidthCm') \
    .add_legend()
plt.show()
# Out:
# c:\python\python37\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\python\python37\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.set_style('white')
sns.FacetGrid(df,hue='Species', aspect=2) \
    .map(sns.distplot,'SepalWidthCm') \
    .add_legend()
plt.show()
# Out:
# c:\python\python37\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\python\python37\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.set_style('white')
sns.FacetGrid(df,hue='Species', aspect=2) \
    .map(sns.distplot,'SepalLengthCm') \
    .add_legend()
plt.show()
# Out:
# c:\python\python37\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\python\python37\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#graph in dark bg: most appropriately separates the classes from each other. 
#Petal Length is one of the major factors for classifying the species

# %%
y = df['Species']
x = df[['PetalLengthCm','PetalWidthCm','SepalLengthCm','SepalWidthCm']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,train_size=0.75, random_state=0)

# %%
x_train.shape
# Out:
# (112, 4)

# %%
x_test.shape
# Out:
# (38, 4)

# %%
y_train.shape
# Out:
# (112,)

# %%
y_test.shape
# Out:
# (38,)

# %%
#model 1
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9736842105263158

# %%
#model 2
from sklearn.svm import SVC
clf = SVC(kernel = 'linear')

# %%
clf.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred2 = clf.predict(x_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9736842105263158

# %%
#model 3
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred3 = dtree.predict(x_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9736842105263158

# %%
#model 4
from sklearn.ensemble import RandomForestClassifier
rcf = RandomForestClassifier()

# %%
rcf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred4 = rcf.predict(x_test)

# %%
accuracy_score(y_test,y_pred4)
# Out:
# 0.9736842105263158

# %%
#conclusion: 
#best accuracy is 0.9736842105263158
#model used can be LogisticRegression
